# %% [markdown]
# # ***Problem Statement***

# %% [markdown]
# # ***Objective***

# %% [markdown]
# # **Importing Libraries**

# %% [markdown]
# ### Importing and uderstanding

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data cleaning

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# **1. Import the dataset**

# %%
df = pd.read_csv("new_insurance_data.csv")
df
# Out:
#         age     sex     bmi  children smoker  Claim_Amount  \
# 0      18.0    male  23.210       0.0     no   29087.54313
# 1     200.0    male  30.140       0.0     no   39053.67437
# 2      18.0    male  33.330       0.0     no   39023.62759
# 3      18.0    male  33.660       0.0     no   28185.39332
# 4      18.0    male  34.100       0.0     no   14697.85941
# ...     ...     ...     ...       ...    ...           ...
# 1333   33.0  female  35.530       0.0    yes   63142.25346
# 1334   31.0  female  38.095       1.0    yes   43419.95227
# 1335   52.0    male  34.485       3.0    yes   52458.92353
# 1336   45.0    male  30.360       0.0    yes   69927.51664
# 1337   54.0  female  47.410       0.0    yes   63982.80926
#
#       past_consultations  num_of_steps  Hospital_expenditure  \
# 0                   17.0      715428.0          4.720921e+06
# 1                    7.0      699157.0          4.329832e+06
# 2                   19.0      702341.0          6.884861e+06
# 3                   11.0      700250.0          4.274774e+06
# 4                   16.0      711584.0          3.787294e+06
# ...                  ...           ...                   ...
# 1333                32.0     1091267.0          1.703805e+08
# 1334                31.0     1107872.0          2.015152e+08
# 1335                25.0     1092005.0          2.236450e+08
# 1336                34.0     1106821.0          2.528924e+08
# 1337                31.0     1100328.0          2.616317e+08
#
#       NUmber_of_past_hospitalizations  Anual_Salary     region      charges
# 0                                 0.0  5.578497e+07  southeast   1121.87390
# 1                                 0.0  1.370089e+07  southeast   1131.50660
# 2                                 0.0  7.352311e+07  southeast   1135.94070
# 3                                 0.0  7.581968e+07  southeast   1136.39940
# 4                                 0.0  2.301232e+07  southeast   1137.01100
# ...                               ...           ...        ...          ...
# 1333                              2.0  3.101107e+09  northwest  55135.40209
# 1334                              2.0  3.484216e+09  northeast  58571.07448
# 1335                              2.0  3.640807e+09  northwest  60021.39897
# 1336                              3.0  4.006359e+09  southeast  62592.87309
# 1337                              3.0  4.117197e+09  southeast  63770.42801
#
# [1338 rows x 13 columns]

# %% [markdown]
# ***2. Visualize first 10 and last 10 rows in the dataset***

# %%
df.head(10)
# Out:
#      age   sex    bmi  children smoker  Claim_Amount  past_consultations  \
# 0   18.0  male  23.21       0.0     no  29087.543130                17.0
# 1  200.0  male  30.14       0.0     no  39053.674370                 7.0
# 2   18.0  male  33.33       0.0     no  39023.627590                19.0
# 3   18.0  male  33.66       0.0     no  28185.393320                11.0
# 4   18.0  male  34.10       0.0     no  14697.859410                16.0
# 5   18.0  male  34.43       0.0     no  26488.339120                20.0
# 6   18.0  male  37.29       0.0     no  33217.365480                13.0
# 7   18.0  male  41.14       0.0     no  46770.585330                12.0
# 8   18.0  male  43.01       0.0     no   9715.650411                17.0
# 9   18.0  male  53.13       0.0     no  17046.585150                19.0
#
#    num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0      715428.0          4.720921e+06                              0.0
# 1      699157.0          4.329832e+06                              0.0
# 2      702341.0          6.884861e+06                              0.0
# 3      700250.0          4.274774e+06                              0.0
# 4      711584.0          3.787294e+06                              0.0
# 5      717162.0          3.696161e+06                              0.0
# 6      699159.0          8.765292e+05                              0.0
# 7      706423.0          4.486741e+06                              0.0
# 8           NaN          9.216440e+06                              0.0
# 9      704425.0          1.458972e+06                              0.0
#
#    Anual_Salary     region    charges
# 0   55784970.05  southeast  1121.8739
# 1   13700885.19  southeast  1131.5066
# 2   73523107.27  southeast  1135.9407
# 3   75819679.60  southeast  1136.3994
# 4   23012320.01  southeast  1137.0110
# 5           NaN  southeast  1137.4697
# 6   69060665.92  southeast  1141.4451
# 7   97193784.44  southeast  1146.7966
# 8   58881971.93  southeast  1149.3959
# 9   94261821.45  southeast  1163.4627

# %%
df.tail(10)
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 1328  44.0  female  38.060       0.0    yes   76028.85348                25.0
# 1329  59.0    male  41.140       1.0    yes   53104.92621                38.0
# 1330  64.0    male  36.960       2.0    yes   65641.24823                28.0
# 1331  28.0    male  36.400       1.0    yes   55590.75527                26.0
# 1332  60.0    male  32.800       0.0    yes   77277.98848                40.0
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 1328     1072324.0           122405879.8                              2.0
# 1329     1079931.0           126353660.6                              2.0
# 1330     1091279.0           123627927.0                              2.0
# 1331     1080113.0           144061589.9                              2.0
# 1332     1095960.0           148034634.6                              2.0
# 1333     1091267.0           170380500.5                              2.0
# 1334     1107872.0           201515184.8                              2.0
# 1335     1092005.0           223644981.3                              2.0
# 1336     1106821.0           252892382.6                              3.0
# 1337     1100328.0           261631699.3                              3.0
#
#       Anual_Salary     region      charges
# 1328  2.430290e+09  southeast  48885.13561
# 1329  2.399896e+09  southeast  48970.24760
# 1330  2.489508e+09  southeast  49577.66240
# 1331  2.682705e+09  southwest  51194.55914
# 1332  2.780642e+09  southwest  52590.82939
# 1333  3.101107e+09  northwest  55135.40209
# 1334  3.484216e+09  northeast  58571.07448
# 1335  3.640807e+09  northwest  60021.39897
# 1336  4.006359e+09  southeast  62592.87309
# 1337  4.117197e+09  southeast  63770.42801

# %% [markdown]
# ***3. Check the size of the dataset***

# %%
df.shape
# Out:
# (1338, 13)

# %% [markdown]
# ***4. Retrieve the overall information about the dataset***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
#  11  region                           1338 non-null   object
#  12  charges                          1338 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 136.0+ KB

# %% [markdown]
# ***5. Check for any null values or and its total count.***

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %% [markdown]
# ***6. Extract the column names of the dataset and insert in a list named as ‘col’.***

# %%
col = df.columns
col
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'Claim_Amount',
#        'past_consultations', 'num_of_steps', 'Hospital_expenditure',
#        'NUmber_of_past_hospitalizations', 'Anual_Salary', 'region', 'charges'],
#       dtype='object')

# %% [markdown]
# ***7. Find the mode of the feature “smoker”***

# %%
mode = df['smoker'].mode()
mode
# Out:
# 0    no
# Name: smoker, dtype: object

# %% [markdown]
# ***8. Find the median of the feature “children” and “age”***

# %%
children_median = df['children'].median()
children_median
# Out:
# 1.0

# %%
age_median = df['age'].median()
age_median
# Out:
# 40.0

# %% [markdown]
# ***9. Fill the columns (features) having object data with “mode” and numerical features with “median”. Use a for loop and if-else condition to perform this activity.***

# %%
for name in col:
    if df[name].dtype == 'object':
        df[name].fillna(mode[0], inplace=True)
    else:
        df[name].fillna(df[name].median(), inplace=True)
# Out:
# <ipython-input-210-dc6bd05f5535>:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[name].fillna(df[name].median(), inplace=True)
# <ipython-input-210-dc6bd05f5535>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[name].fillna(mode[0], inplace=True)

# %% [markdown]
# ***10. Re-check the data set whether it is replaced with median and mode.***

# %%
df.isnull().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %% [markdown]
# ***11. Plot a histogram plot for every numerical feature (Integer or float) in the dataset using matplotlib library. The X-axis should be the feature name and Y-axis should be the count. Use for loop and if condition to perform this operation in less than six lines of code.***

# %%
for column in df.select_dtypes(include='number'):
    plt.figure(figsize=(5, 2.5))
    sns.histplot(df[column], color='blue', edgecolor='black', bins=50)
    plt.title(f'{column}')
    plt.show()

# %% [markdown]
# ***12. Plot a vertical boxplot to plot for every numerical feature (integer or float) in the dataset using matplotlib library. Identify whether there are any outliers in it.***

# %%
for column in df.select_dtypes(include='number'):
    plt.figure(figsize=(5, 2.5))
    sns.boxplot(df[column])
    plt.title(f'{column}')
    plt.show()

# %% [markdown]
# ***13. Create a table having statistical description and identify whether there are outliers by observing whether 75 percentile is far away from the maximum value. List out the features having maximum value is much higher than 75 percentiles.***

# %%
stats = df.describe()
stats
# Out:
#                age          bmi     children  Claim_Amount  \
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.450673    30.664518     1.090433  33364.874093
# std      14.649463     6.094853     1.199619  15535.345575
# min      18.000000    15.960000     0.000000   1920.136268
# 25%      27.000000    26.315000     0.000000  20947.645198
# 50%      40.000000    30.400000     1.000000  33700.310675
# 75%      51.000000    34.656250     2.000000  44978.873188
# max     200.000000    53.130000     5.000000  77277.988480
#
#        past_consultations  num_of_steps  Hospital_expenditure  \
# count         1338.000000  1.338000e+03          1.338000e+03
# mean            15.215247  9.100143e+05          1.581682e+07
# std              7.450962  9.178320e+04          2.665699e+07
# min              1.000000  6.954300e+05          2.945253e+04
# 25%              9.000000  8.474898e+05          4.084941e+06
# 50%             15.000000  9.143000e+05          7.490337e+06
# 75%             20.000000  9.715100e+05          1.082630e+07
# max             40.000000  1.107872e+06          2.616317e+08
#
#        NUmber_of_past_hospitalizations  Anual_Salary       charges
# count                      1338.000000  1.338000e+03   1338.000000
# mean                          1.060538  3.686636e+08  13270.422265
# std                           0.533189  5.658157e+08  12110.011237
# min                           0.000000  2.747072e+06   1121.873900
# 25%                           1.000000  7.755085e+07   4740.287150
# 50%                           1.000000  1.419361e+08   9382.033000
# 75%                           1.000000  3.225202e+08  16639.912515
# max                           3.000000  4.117197e+09  63770.428010

# %%
# Identify potential outliers
outlier_features = []
for column in stats.columns:
    if stats.loc['max', column] > 1.5 * stats.loc['75%', column]:
        outlier_features.append(column)


print("Features where max is significantly higher than 75th percentile:")
print(outlier_features)
# Out:
# Features where max is significantly higher than 75th percentile:
# ['age', 'bmi', 'children', 'Claim_Amount', 'past_consultations', 'Hospital_expenditure', 'NUmber_of_past_hospitalizations', 'Anual_Salary', 'charges']

# %% [markdown]
# ***14. Calculate IQR , upper limit , and lower limit, and finally eliminate the outliers.***

# %%
def remove_outliers_iqr(df, exclude_column):
    data = df.copy()  # Create a copy of the DataFrame
    for col in data.columns:
        if col == exclude_column or not pd.api.types.is_numeric_dtype(data[col]):
            continue
        Q1 = data[col].quantile(0.25)
        Q3 = data[col].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        # Remove rows with outliers in the current column
        data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)]
    return data

df_cleaned = remove_outliers_iqr(df, exclude_column='charges')
df=df_cleaned

# %% [markdown]
# ***15. Replot the boxplot and check whether there are oultliers. If you found any outliers report it in the assignment.***

# %%
for column in df.select_dtypes(include='number'):
    plt.figure(figsize=(5, 2.5))
    sns.boxplot(df[column])
    plt.title(f'{column}')
    plt.show()

# %% [markdown]
# ***There are still outliers in Annual_Salary and BMI***

# %% [markdown]
# ***16. Create a correlation matrix and plot a heat map to identify the most correlated features. Report the most correlated features from the heat map.***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 878 entries, 12 to 1069
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              878 non-null    float64
#  1   sex                              878 non-null    object
#  2   bmi                              878 non-null    float64
#  3   children                         878 non-null    float64
#  4   smoker                           878 non-null    object
#  5   Claim_Amount                     878 non-null    float64
#  6   past_consultations               878 non-null    float64
#  7   num_of_steps                     878 non-null    float64
#  8   Hospital_expenditure             878 non-null    float64
#  9   NUmber_of_past_hospitalizations  878 non-null    float64
#  10  Anual_Salary                     878 non-null    float64
#  11  region                           878 non-null    object
#  12  charges                          878 non-null    float64
# dtypes: float64(10), object(3)
# memory usage: 96.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

df['sex'] = labelencoder.fit_transform(df['sex'])
df['smoker'] = labelencoder.fit_transform(df['smoker'])
df['region'] = labelencoder.fit_transform(df['region'])

# %%
df_corr = df.corr()
plt.figure(figsize = (10,10))
sns.heatmap(df_corr,annot = True, cmap = 'coolwarm', linewidth = 0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
target_corr = df_corr['charges'].sort_values(ascending = False).drop('charges')
sns.heatmap(target_corr.to_frame(), annot = True, cmap = 'coolwarm', linewidth = 0.5, annot_kws = {'size': 10})
plt.show()

# %% [markdown]
# **num_of_steps, Anual_salary**

# %%
df = df[['num_of_steps', 'Anual_Salary','age','smoker','charges']]
df1=df

# %% [markdown]
# ***17. Apply label encoder / one hot encoding where ever required to convert object data into numerical representation.***

# %%
# from sklearn.preprocessing import LabelEncoder
# labelencoder = LabelEncoder()

# df['sex'] = labelencoder.fit_transform(df['sex'])
# df['smoker'] = labelencoder.fit_transform(df['smoker'])
# df['region'] = labelencoder.fit_transform(df['region'])

# %% [markdown]
# ***18. Apply standardization or normalization to require for algorithms like Support vector regressor and Neural networks.***

# %%
from sklearn.preprocessing import MinMaxScaler

features = df.drop('charges', axis = 1)

scaler = MinMaxScaler()

scaled_data = scaler.fit_transform(features)

scaled_df = pd.DataFrame(scaled_data, columns=features.columns, index=features.index)

df = scaled_df
df['charges'] = df1['charges']
df
# Out:
#       num_of_steps  Anual_Salary       age  smoker      charges
# 12        0.000000      0.233334  0.021739     0.0   1242.81600
# 151       0.209708      0.125006  0.152174     0.0   2523.16950
# 152       0.290949      0.022879  0.086957     0.0   2527.81865
# 153       0.173185      0.108801  0.152174     0.0   2534.39375
# 154       0.167573      0.043663  0.043478     0.0   2566.47070
# ...            ...           ...       ...     ...          ...
# 1041      0.946730      0.988856  0.130435     0.0  18955.22017
# 1046      0.997530      0.980471  0.239130     1.0  19107.77960
# 1050      0.924230      0.989418  0.282609     1.0  19350.36890
# 1062      1.000000      0.361122  0.543478     1.0  19798.05455
# 1069      0.998373      0.361122  0.369565     1.0  20234.85475
#
# [878 rows x 5 columns]

# %% [markdown]
# ***19. Skewness should also be addressed using log method for algorithms like linear regression.***

# %%
df['num_of_steps'] = np.log1p(df['num_of_steps'])
df['Anual_Salary'] = np.log1p(df['Anual_Salary'])
df['age'] = np.log1p(df['age'])

# %% [markdown]
# ***20. Split the data set into Independent and dependant variables.***

# %%
x=df[['num_of_steps','Anual_Salary'	,'age'	,'smoker']]
y=df['charges']

# %% [markdown]
# ***21. Split the dataset into training and testing data (X_train, X_test, y_train, y_test) with training size = 80% and testing size = 20 %)***

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ***22. Apply PCA to reduce the number of features. (If number of features are reduced, report it in
# your google colab file)***

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the features before PCA
features =['num_of_steps','Anual_Salary'	,'age'	,'smoker']
scaler = StandardScaler().fit_transform(df1[features])


# Apply PCA
from sklearn.decomposition import PCA
pca = PCA(n_components=2)  # Choose the desired number of components
pca_result = pca.fit_transform(scaler)


# Add PCA results to the DataFrame
df1['pca1'] = pca_result[:, 0]
df1['pca2'] = pca_result[:, 1]
# Out:
# <ipython-input-228-aac5b14ca1cb>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['pca1'] = pca_result[:, 0]
# <ipython-input-228-aac5b14ca1cb>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['pca2'] = pca_result[:, 1]

# %% [markdown]
# ***23. Import all the regression models from Scikit learn and fit those in selected algorithms. The
# regression models to be imported are (1. Linear Regression, 2. Ridge Regression, 3. Lasso
# Regression, 4. ElasticNet Regression, 5. Decision Tree Regressor, 6. Random Forest
# Regressor, 7. Gradient Boosting Regressor, 8. Support Vector Regressor, 9. K-Nearest
# Neighbors regressor, 10. Neural Network)***

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor

models = {
    "Linear_Regression": LinearRegression(),
    "Ridge Regression": Ridge(),
    "Lasso Regression": Lasso(),
    "ElasticNet Regression": ElasticNet(),
    "Decision Tree Regressor": DecisionTreeRegressor(),
    "Random Forest Regressor": RandomForestRegressor(),
    "Gradient Boosting Regressor": GradientBoostingRegressor(),
    "Support Vector Regressor": SVR(),
    "K-Nearest Neighbors Regressor": KNeighborsRegressor(),
    "Neural Network": MLPRegressor()
}

# %% [markdown]
# ***24. Fit the data into it***

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

def evaluate_model(y_true, y_pred):
  mae = mean_absolute_error(y_true, y_pred)
  rmse = np.sqrt(mean_squared_error(y_true, y_pred))
  r2 = r2_score(y_true, y_pred)
  return mae, rmse, r2

results = {}

for name, model in models.items():
  model.fit(x_train, y_train)
  y_pred = model.predict(x_test)
  mae, rmse, r2 = evaluate_model(y_test, y_pred)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ***25. Compute its metrics such as MSE, RMSE, R2 score.***

# %%
results = {}
for name, model in models.items(): # When you call items() on a dictionary, returns a list of the dictionary’s key-value tuple pairs.
                                   # Here "name" represents the "key", and "model" represents the "value"
  if name in ["Neural Network"]: # Standardised value is only applied to support vector regressor and Neural network
        # Apply scaling for models that need it
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
  else:
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)

        # Compute evaluation metrics
  mae, rmse, r2 = evaluate_model(y_test, y_pred)
  results[name] = {"MAE": mae, "RMSE": rmse, "R²": r2}
results2_df = pd.DataFrame(results).T
print(results2_df)
# Out:
#                                        MAE         RMSE        R²
# Linear_Regression               680.161328   912.202795  0.948321
# Ridge Regression                727.335205  1021.372575  0.935211
# Lasso Regression                679.754395   911.359235  0.948417
# ElasticNet Regression          3052.689311  3652.839829  0.171311
# Decision Tree Regressor         605.562322   794.213281  0.960825
# Random Forest Regressor         433.080282   548.375322  0.981324
# Gradient Boosting Regressor     400.034124   505.850735  0.984108
# Support Vector Regressor       3257.753829  3936.814608  0.037457
# K-Nearest Neighbors Regressor   472.320290   671.389246  0.972005
# Neural Network                 8507.653324  9393.250430 -4.479764
# /usr/local/lib/python3.10/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %% [markdown]
# ***26. Eventually select the best fit model for deployment.***

# %%
# Gradient Boosting Regressor is the most suitable choice for deployment in terms of performance (MAE, RMSE, and R²)
